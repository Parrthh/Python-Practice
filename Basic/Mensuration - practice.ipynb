# %%
#Q5 Find out area of rectangle and take user input
l = float(input("Length of the rectangle : "));
b = float(input("Breadth of the rectangle : "));
Area = l*b
print("Area of the rectangle : ", Area)
# Out:
# Length of the rectangle : 6
# Breadth of the rectangle : 7
# Area of the rectangle :  42.0

# %%
#Q6 Find out area of square and take user input
s = float(input("Side of the square : "));
Area = s*s
print("Area of the square : ", Area)

# %%
#Q7 Find out area of circle and take user input
r = float(input("Radius of the circle : "));
Area = 3.142*r*r
print("Area of the circle : ", Area)

# %%
#Q8 Find out perimeter of rectange
l = float(input("Length of the rectangle : "));
b = float(input("Breadth of the rectangle : "));
Perimeter = l + b
print("Perimeter of the rectangle ", Perimeter)

# %%
#Q9 Find out perimeter of square
s = float(input("Side of the square : "));
Perimeter = 4*s
print("Perimeter of square ", Perimeter)

# %%
#Q10 Find out circumference of circle
r = float(input("Radius of the circle : "));
Circumference = 2*3.142*r
print("Circumference of the circle : ", Circumference)

# %%
#Q11 Find out volume of the cube
a = float(input("Side of cube : "));
Volume = a*a*a
print("Volume of the cube: ", Volume)

# %%
#Q12 Find out volume of cuboid
l = float(input("Length of the cuboid : "));
b = float(input("Breadth of the cuboid : "));
h = float(input("Height of the cuboid : "));
Volume = l*b*h
print("Volume of the cuboid: ", Volume)

# %%
#Q13 Find out total surface area of cube
a = float(input("Side of the cube"));
TSA = 6*a*a
print("TSA of the cube: ", TSA)

# %%
#Q14 Find out total surface area of cuboid
l = float(input("Length of the cuboid : "));
w = float(input("Weidth of the cuboid : "));
h = float(input("Height of the cuboid : "));
TSA = 2*l*w+2*l*h+2*h*w
print("TSA of the cuboid: ", TSA)
