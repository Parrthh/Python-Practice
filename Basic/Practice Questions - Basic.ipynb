# %% [markdown]
# ### Practice Questions - Basic

# %%
#Q1 Take two variables of number and character and concatenate it: ex-name and birthdate
a = 'Parth Kharkar'
b = '18/10/2000'
print(a+" "+b)

# %%
#Q2 Same as previous but for email id (take 3 variables)
a = 'parthkharkar'
b = '@'
c = 'gmail.com'
print(a+b+c)

# %%
#Q3 Take 3 variables and print your full name
a = 'Parth'
b = 'Kalpesh'
c = 'Kharkar'
print(a+" "+b+" "+c)

# %% [markdown]
# #### Revision Practice

# %%
a = '21'
b =  'Parths age'
print(b+"-"+a)

# %%
a = 50
print(type(a))

# %%
b = 5.65
print(type(b))

# %%
a = 100
b = 125
print(type(a>b))

# %%
p = [1,2,4]
print(type(p))

# %%
a = (2,3,40)
print(type(a))

# %%
x = {234,345,456}
print(type(x))

# %% [markdown]
# ### Input - Output

# %%
#Q4 Find out the percentage of student (Yours) (5 subjects, total marks 500,) - User input
name = input("Name of the student: ");
English = float(input("Enter marks for English : "));
Maths = float(input("Enter marks for maths : "));
Physics = float(input("Enter marks for physics : "));
Chemistry = float(input("Enter marks for chemistry : "));
Biology = float(input("Enter marks for biology : "))
Gained = English + Maths + Physics + Chemistry + Biology
Total = 500
Percentage = (Gained/Total)*100
print(name, "has scored",Percentage,'%')
# Out:
# Name of the student: Parth
# Enter marks for English : 80
# Enter marks for maths : 85
# Enter marks for physics : 81
# Enter marks for chemistry : 87
# Enter marks for biology : 70
# Parth has scored 80.60000000000001 %
